# %% [markdown]
# # Comparison
#
# The closest colors in the Vakio palette (using default parameters) are provided for some commonly used colors, along with their lightness and chroma values, as well as perceptual distances.

# %%
from vakio import *
import vakio.view as view
palette = create_palette()

# %% [markdown]
# ## Github Light theme
#
# Colors from GitHub Light Default [theme for VS Code](https://marketplace.visualstudio.com/items?itemName=GitHub.github-vscode-theme). Only colors with chroma > 100 are shown.

# %%
github = {
 '#01458F',
 '#0163F7',
 '#0550AE',
 '#0A3069',
 '#0F5801',
 '#116329',
 '#1D8902',
 '#316BCD',
 '#800080',
 '#82071E',
 '#8250DF',
 '#8B010C',
 '#953800',
 '#CD3131',
 '#CD9731',
 '#CF222E',
 '#D50118',
}
view.closest(github, palette)
# Out:
# <table style='border-collapse: collapse;'>
# <tr style='
#     border-bottom: 2px solid #deddda;
# '><th style='
#     text-align: center;
# '>color and its closest match</th><th style='
#     text-align: center;
#     background: #f6f5f4;
# '>dist</th></tr>
#
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(1.0, 69.0, 143.0);
# '>■ #01458F L=40 c=137 cobalt</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.095</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 45.0, 189.0);
# '>■ #002dbd L=40 c=224 true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #D50118 L=55 c=223 red</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.000</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118 L=55 c=223 red</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(10.0, 48.0, 105.0);
# '>■ #0A3069 L=32 c=108 marine</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.141</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 45.0, 189.0);
# '>■ #002dbd L=40 c=224 true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(15.0, 88.0, 1.0);
# '>■ #0F5801 L=40 c=132 deep green</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.000</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(15.0, 88.0, 1.0);
# '>■ #0f5801 L=40 c=132 deep green</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(205.0, 49.0, 49.0);
# '>■ #CD3131 L=56 c=193 reddish</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.033</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118 L=55 c=223 red</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(49.0, 107.0, 205.0);
# '>■ #316BCD L=54 c=164 medium blue</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.087</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(27.0, 93.0, 255.0);
# '>■ #1b5dff L=55 c=248 bright blue</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(29.0, 137.0, 2.0);
# '>■ #1D8902 L=55 c=180 emerald green</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.000</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(29.0, 137.0, 2.0);
# '>■ #1d8902 L=55 c=180 emerald green</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(207.0, 34.0, 46.0);
# '>■ #CF222E L=55 c=205 cherry</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.023</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118 L=55 c=223 red</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(205.0, 151.0, 49.0);
# '>■ #CD9731 L=71 c=130 camel</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.050</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(220.0, 164.0, 1.0);
# '>■ #dca401 L=75 c=154 burnt yellow</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(17.0, 99.0, 41.0);
# '>■ #116329 L=44 c=118 pine</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.047</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(15.0, 88.0, 1.0);
# '>■ #0f5801 L=40 c=132 deep green</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(139.0, 1.0, 12.0);
# '>■ #8B010C L=40 c=163 crimson</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.000</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(139.0, 1.0, 12.0);
# '>■ #8b010c L=40 c=163 crimson</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(130.0, 80.0, 223.0);
# '>■ #8250DF L=56 c=207 purpley</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.071</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(147.0, 53.0, 223.0);
# '>■ #9335df L=55 c=240 violet</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(1.0, 99.0, 247.0);
# '>■ #0163F7 L=55 c=234 bright blue</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.023</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(27.0, 93.0, 255.0);
# '>■ #1b5dff L=55 c=248 bright blue</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(5.0, 80.0, 174.0);
# '>■ #0550AE L=45 c=164 cobalt</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.084</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 45.0, 189.0);
# '>■ #002dbd L=40 c=224 true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(149.0, 56.0, 0.0);
# '>■ #953800 L=47 c=137 auburn</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.100</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(139.0, 1.0, 12.0);
# '>■ #8b010c L=40 c=163 crimson</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(128.0, 0.0, 128.0);
# '>■ #800080 L=42 c=193 darkish purple</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.024</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(118.0, 1.0, 122.0

# %% [markdown]
# ## ANSI colors
#
# The six original [ANSI colors](https://en.wikipedia.org/wiki/ANSI_escape_code#3-bit_and_4-bit) as pinned down by the [XKCD color survey](https://blog.xkcd.com/2010/05/03/color-survey-results/).

# %%
ansi_colors = [
    view.XKCD_COLORS["xkcd:" + name] for name in 
    ["red", "green", "blue", "yellow", "magenta", "cyan"]
]
view.closest(ansi_colors, palette)
# Out:
# <table style='border-collapse: collapse;'>
# <tr style='
#     border-bottom: 2px solid #deddda;
# '><th style='
#     text-align: center;
# '>color and its closest match</th><th style='
#     text-align: center;
#     background: #f6f5f4;
# '>dist</th></tr>
#
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(229.0, 0.0, 0.0);
# '>■ #e50000 L=58 c=238 red</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.036</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118 L=55 c=223 red</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(21.0, 176.0, 26.0);
# '>■ #15b01a L=66 c=215 green</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.008</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 174.0, 13.0);
# '>■ #00ae0d L=65 c=219 green</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(3.0, 67.0, 223.0);
# '>■ #0343df L=47 c=241 blue</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.074</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 45.0, 189.0);
# '>■ #002dbd L=40 c=224 true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(255.0, 255.0, 20.0);
# '>■ #ffff14 L=97 c=209 yellow</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.261</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(220.0, 164.0, 1.0);
# '>■ #dca401 L=75 c=154 burnt yellow</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(194.0, 0.0, 120.0);
# '>■ #c20078 L=53 c=221 magenta</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.051</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(198.0, 4.0, 142.0);
# '>■ #c6048e L=55 c=232 magenta</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 255.0, 255.0);
# '>■ #00ffff L=91 c=155 cyan</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.362</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 129.0, 137.0);
# '>■ #008189 L=55 c=93 dark cyan</td>
# </tr></table>

# %% [markdown]
# ## Rainbow
#
# Colors of rainbow can be useful for [bracket pair colorization](https://code.visualstudio.com/updates/v1_60#_high-performance-bracket-pair-colorization)

# %%
rainbow_colors = [
    view.XKCD_COLORS["xkcd:" + name] for name in 
    ["red", "orange", "yellow", "green", "blue", "violet"]
]
view.closest(rainbow_colors, palette)
# Out:
# <table style='border-collapse: collapse;'>
# <tr style='
#     border-bottom: 2px solid #deddda;
# '><th style='
#     text-align: center;
# '>color and its closest match</th><th style='
#     text-align: center;
#     background: #f6f5f4;
# '>dist</th></tr>
#
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(229.0, 0.0, 0.0);
# '>■ #e50000 L=58 c=238 red</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.036</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118 L=55 c=223 red</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(249.0, 115.0, 6.0);
# '>■ #f97306 L=70 c=188 orange</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.062</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(219.0, 114.0, 1.0);
# '>■ #db7201 L=66 c=162 pumpkin</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(255.0, 255.0, 20.0);
# '>■ #ffff14 L=97 c=209 yellow</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.261</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(220.0, 164.0, 1.0);
# '>■ #dca401 L=75 c=154 burnt yellow</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(21.0, 176.0, 26.0);
# '>■ #15b01a L=66 c=215 green</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.008</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 174.0, 13.0);
# '>■ #00ae0d L=65 c=219 green</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(3.0, 67.0, 223.0);
# '>■ #0343df L=47 c=241 blue</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.074</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 45.0, 189.0);
# '>■ #002dbd L=40 c=224 true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(154.0, 14.0, 234.0);
# '>■ #9a0eea L=55 c=276 violet</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.038</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(147.0, 53.0, 223.0);
# '>■ #9335df L=55 c=240 violet</td>
# </tr></table>
