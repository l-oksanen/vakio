# %% [markdown]
# # Comparison
#
# The closest colors in the Vakio palette (using default parameters) are provided for some commonly used colors, along with their lightness and chroma values, as well as perceptual distances.

# %%
from vakio import *
import vakio.view as view
palette = create_palette()

# %% [markdown]
# ## Github Light theme
#
# Colors from GitHub Light Default [theme for VS Code](https://marketplace.visualstudio.com/items?itemName=GitHub.github-vscode-theme). Only colors with chroma > 100 are shown.

# %%
github = [
 '#1D8902',
 '#0F5801',
 '#116329',
 '#01458F',
 '#0550AE',
 '#0A3069',
 '#316BCD',
 '#0163F7',
 '#8250DF',
 '#800080',
 '#82071E',
 '#CF222E',
 '#CD3131',
 '#8B010C',
 '#D50118',
 '#953800',
 '#CD9731'
]
view.closest(github, palette)
# Out:
# <table style='border-collapse: collapse;'>
# <tr style='
#     border-bottom: 2px solid #deddda;
# '><th style='
#     text-align: center !important;
# '>color and its closest match</th><th style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>dist</th></tr>
#
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(29.0, 137.0, 2.0);
# '>■ #1D8902  55 180 emerald green</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.000</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(29.0, 137.0, 2.0);
# '>■ #1d8902  55 180 emerald green</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(15.0, 88.0, 1.0);
# '>■ #0F5801  40 132 deep green</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.000</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(15.0, 88.0, 1.0);
# '>■ #0f5801  40 132 deep green</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(17.0, 99.0, 41.0);
# '>■ #116329  44 118 spruce</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.031</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(15.0, 88.0, 1.0);
# '>■ #0f5801  40 132 deep green</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(1.0, 69.0, 143.0);
# '>■ #01458F  40 137 cobalt</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.090</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(0.0, 45.0, 189.0);
# '>■ #002dbd  40 224 true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(5.0, 80.0, 174.0);
# '>■ #0550AE  45 164 cobalt</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.070</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(0.0, 45.0, 189.0);
# '>■ #002dbd  40 224 true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(10.0, 48.0, 105.0);
# '>■ #0A3069  32 108 marine</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.103</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(2.0, 82.0, 88.0);
# '>■ #025258  40  67 deep teal</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(49.0, 107.0, 205.0);
# '>■ #316BCD  54 164 cornflower blue</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.085</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(27.0, 93.0, 255.0);
# '>■ #1b5dff  55 248 bright blue</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(1.0, 99.0, 247.0);
# '>■ #0163F7  55 234 bright blue</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.018</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(27.0, 93.0, 255.0);
# '>■ #1b5dff  55 248 bright blue</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(130.0, 80.0, 223.0);
# '>■ #8250DF  56 207 purpley</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.051</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(147.0, 53.0, 223.0);
# '>■ #9335df  55 240 violet</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(128.0, 0.0, 128.0);
# '>■ #800080  42 193 darkish purple</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.017</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(118.0, 1.0, 122.0);
# '>■ #76017a  40 185 darkish purple</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(130.0, 7.0, 30.0);
# '>■ #82071E  39 151 wine red</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.022</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(139.0, 1.0, 12.0);
# '>■ #8b010c  40 163 crimson</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(207.0, 34.0, 46.0);
# '>■ #CF222E  55 205 cherry</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.020</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118  55 223 red</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(205.0, 49.0, 49.0);
# '>■ #CD3131  56 193 reddish</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.031</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118  55 223 red</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(139.0, 1.0, 12.0);
# '>■ #8B010C  40 163 crimson</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.000</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(139.0, 1.0, 12.0);
# '>■ #8b010c  40 163 crimson</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #D50118  55 223 red</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.000</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118  55 223 red</td>
# </tr>
# <tr

# %% [markdown]
# ## ANSI colors
#
# The six original [ANSI colors](https://en.wikipedia.org/wiki/ANSI_escape_code#3-bit_and_4-bit) as pinned down by the [XKCD color survey](https://blog.xkcd.com/2010/05/03/color-survey-results/).

# %%
ansi_colors = [
    view.XKCD_COLORS["xkcd:" + name] for name in 
    ["red", "green", "blue", "yellow", "magenta", "cyan"]
]
view.closest(ansi_colors, palette)
# Out:
# <table style='border-collapse: collapse;'>
# <tr style='
#     border-bottom: 2px solid #deddda;
# '><th style='
#     text-align: center !important;
# '>color and its closest match</th><th style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>dist</th></tr>
#
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(229.0, 0.0, 0.0);
# '>■ #e50000  58 238 red</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.025</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118  55 223 red</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(21.0, 176.0, 26.0);
# '>■ #15b01a  66 215 green</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.006</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(0.0, 174.0, 13.0);
# '>■ #00ae0d  65 219 green</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(3.0, 67.0, 223.0);
# '>■ #0343df  47 241 blue</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.048</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(0.0, 45.0, 189.0);
# '>■ #002dbd  40 224 true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(255.0, 255.0, 20.0);
# '>■ #ffff14  97 209 yellow</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.168</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(220.0, 164.0, 1.0);
# '>■ #dca401  75 154 burnt yellow</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(194.0, 0.0, 120.0);
# '>■ #c20078  53 221 magenta</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.032</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(198.0, 4.0, 142.0);
# '>■ #c6048e  55 232 magenta</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(0.0, 255.0, 255.0);
# '>■ #00ffff  91 155 cyan</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.234</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(0.0, 129.0, 137.0);
# '>■ #008189  55  93 dark cyan</td>
# </tr></table>

# %% [markdown]
# ## Rainbow
#
# Colors of rainbow can be useful for [bracket pair colorization](https://code.visualstudio.com/updates/v1_60#_high-performance-bracket-pair-colorization)

# %%
rainbow_colors = [
    view.XKCD_COLORS["xkcd:" + name] for name in 
    ["red", "orange", "yellow", "green", "blue", "violet"]
]
view.closest(rainbow_colors, palette)
# Out:
# <table style='border-collapse: collapse;'>
# <tr style='
#     border-bottom: 2px solid #deddda;
# '><th style='
#     text-align: center !important;
# '>color and its closest match</th><th style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>dist</th></tr>
#
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(229.0, 0.0, 0.0);
# '>■ #e50000  58 238 red</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.025</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118  55 223 red</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(249.0, 115.0, 6.0);
# '>■ #f97306  70 188 orange</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.043</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(219.0, 114.0, 1.0);
# '>■ #db7201  66 162 pumpkin</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(255.0, 255.0, 20.0);
# '>■ #ffff14  97 209 yellow</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.168</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(220.0, 164.0, 1.0);
# '>■ #dca401  75 154 burnt yellow</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(21.0, 176.0, 26.0);
# '>■ #15b01a  66 215 green</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.006</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(0.0, 174.0, 13.0);
# '>■ #00ae0d  65 219 green</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(3.0, 67.0, 223.0);
# '>■ #0343df  47 241 blue</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.048</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(0.0, 45.0, 189.0);
# '>■ #002dbd  40 224 true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(154.0, 14.0, 234.0);
# '>■ #9a0eea  55 276 violet</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.037</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     color: rgb(147.0, 53.0, 223.0);
# '>■ #9335df  55 240 violet</td>
# </tr></table>
