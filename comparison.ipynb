# %% [markdown]
# # Comparison
#
# The closest colors in the Vakio palette (using default parameters) are provided for some commonly used colors, along with their corresponding lightness values and perceptual distances.

# %%
from vakio import *
import vakio.view as view
palette = create_palette()

# %% [markdown]
# ## Github Light theme
#
# The colors are taken from a [tinted base24 theme](https://github.com/tinted-theming/schemes/blob/spec-0.11/base24/github.yaml).

# %%
# NOTE To keep dependencies of the package minimal
# PyYAML must be installed manually for these comparisons
import yaml
with open("examples/github.yaml", "r") as f:
    data = yaml.safe_load(f)
github_dark_colors = [
    h for k, h in data['palette'].items() if k in base24_dark_colors
]
view.closest(github_dark_colors, palette)
# Out:
# <table style='border-collapse: collapse;'>
# <tr style='
#     border-bottom: 2px solid #deddda;
# '><th style='
#     text-align: center;
# '>color and its closest match</th><th style='
#     text-align: center;
#     background: #f6f5f4;
# '>dist</th></tr>
#
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(250.0, 69.0, 73.0);
# '>■ #fa4549 66 light red</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.109</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118 55 red</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(225.0, 111.0, 36.0);
# '>■ #e16f24 67 pumpkin</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.037</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(225.0, 119.0, 1.0);
# '>■ #e17701 68 pumpkin</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(191.0, 135.0, 0.0);
# '>■ #bf8700 66 ochre</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.105</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(225.0, 119.0, 1.0);
# '>■ #e17701 68 pumpkin</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(45.0, 164.0, 78.0);
# '>■ #2da44e 63 emerald</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.094</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(29.0, 137.0, 2.0);
# '>■ #1d8902 55 emerald green</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(51.0, 157.0, 155.0);
# '>■ #339D9B 64 sea</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.091</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 129.0, 137.0);
# '>■ #008189 55 dark cyan</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(33.0, 139.0, 255.0);
# '>■ #218bff 64 dodger blue</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.099</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 114.0, 205.0);
# '>■ #0072cd 55 medium blue</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(164.0, 117.0, 249.0);
# '>■ #a475f9 67 light urple</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.223</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(181.0, 1.0, 192.0);
# '>■ #b501c0 55 barney</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(77.0, 45.0, 0.0);
# '>■ #4d2d00 33 brown</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.172</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(139.0, 1.0, 12.0);
# '>■ #8b010c 40 crimson</td>
# </tr></table>

# %% [markdown]
# Apart from the extra colors, the default _bright_ colors of Vakio have lower lightness than the _dark_ colors of Github Light.

# %% [markdown]
# ## Miscellaneous
#
# ### ANSI colors
#
# The six original [ANSI colors](https://en.wikipedia.org/wiki/ANSI_escape_code#3-bit_and_4-bit) as pinned down by the [XKCD color survey](https://blog.xkcd.com/2010/05/03/color-survey-results/).

# %%
ansi_colors = [
    view.XKCD_COLORS["xkcd:" + name] for name in 
    ["red", "green", "blue", "yellow", "magenta", "cyan"]
]
view.closest(ansi_colors, palette)
# Out:
# <table style='border-collapse: collapse;'>
# <tr style='
#     border-bottom: 2px solid #deddda;
# '><th style='
#     text-align: center;
# '>color and its closest match</th><th style='
#     text-align: center;
#     background: #f6f5f4;
# '>dist</th></tr>
#
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(229.0, 0.0, 0.0);
# '>■ #e50000 58 red</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.036</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118 55 red</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(21.0, 176.0, 26.0);
# '>■ #15b01a 66 green</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.115</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(29.0, 137.0, 2.0);
# '>■ #1d8902 55 emerald green</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(3.0, 67.0, 223.0);
# '>■ #0343df 47 blue</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.073</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 43.0, 191.0);
# '>■ #002bbf 40 true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(255.0, 255.0, 20.0);
# '>■ #ffff14 97 yellow</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.180</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(250.0, 194.0, 5.0);
# '>■ #fac205 84 goldenrod</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(194.0, 0.0, 120.0);
# '>■ #c20078 53 magenta</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.193</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(181.0, 1.0, 192.0);
# '>■ #b501c0 55 barney</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 255.0, 255.0);
# '>■ #00ffff 91 cyan</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.362</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 129.0, 137.0);
# '>■ #008189 55 dark cyan</td>
# </tr></table>

# %% [markdown]
# ### Rainbow
#
# Colors of rainbow can be useful for [bracket pair colorization](https://code.visualstudio.com/updates/v1_60#_high-performance-bracket-pair-colorization)

# %%
rainbow_colors = [
    view.XKCD_COLORS["xkcd:" + name] for name in 
    ["red", "orange", "yellow", "green", "blue", "indigo", "violet"]
]
view.closest(rainbow_colors, palette)
# Out:
# <table style='border-collapse: collapse;'>
# <tr style='
#     border-bottom: 2px solid #deddda;
# '><th style='
#     text-align: center;
# '>color and its closest match</th><th style='
#     text-align: center;
#     background: #f6f5f4;
# '>dist</th></tr>
#
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(229.0, 0.0, 0.0);
# '>■ #e50000 58 red</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.036</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(213.0, 1.0, 24.0);
# '>■ #d50118 55 red</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(249.0, 115.0, 6.0);
# '>■ #f97306 70 orange</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.053</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(225.0, 119.0, 1.0);
# '>■ #e17701 68 pumpkin</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(255.0, 255.0, 20.0);
# '>■ #ffff14 97 yellow</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.180</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(250.0, 194.0, 5.0);
# '>■ #fac205 84 goldenrod</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(21.0, 176.0, 26.0);
# '>■ #15b01a 66 green</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.115</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(29.0, 137.0, 2.0);
# '>■ #1d8902 55 emerald green</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(3.0, 67.0, 223.0);
# '>■ #0343df 47 blue</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.073</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(0.0, 43.0, 191.0);
# '>■ #002bbf 40 true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(56.0, 2.0, 130.0);
# '>■ #380282 32 indigo</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.178</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(1.0, 69.0, 143.0);
# '>■ #01458f 40 cobalt</td>
# </tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(154.0, 14.0, 234.0);
# '>■ #9a0eea 55 violet</td>
#
# <td rowspan='2' style='
#     text-align: center;
#     background: #f6f5f4;
# '>0.147</td></tr>
# <tr style='
#     background: #fff;
#     text-align: left;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     color: rgb(181.0, 1.0, 192.0);
# '>■ #b501c0 55 barney</td>
# </tr></table>
