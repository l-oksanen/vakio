# %% [markdown]
# # Comparison
#
# The closest colors in the Vakio palette (using default parameters) are provided for some commonly used colors, along with their lightness and chroma values, as well as perceptual distances.

# %%
from vakio import *
import vakio.view as view
palette = create_palette()

# %% [markdown]
# ## Github Light theme
#
# Colors from GitHub Light Default [theme for VS Code](https://marketplace.visualstudio.com/items?itemName=GitHub.github-vscode-theme). Only colors with chroma > 100 are shown.

# %%
github = [
 '#1D8902',
 '#0F5801',
 '#116329',
 '#01458F',
 '#0550AE',
 '#0A3069',
 '#316BCD',
 '#0163F7',
 '#8250DF',
 '#800080',
 '#82071E',
 '#CF222E',
 '#CD3131',
 '#8B010C',
 '#D50118',
 '#953800',
 '#CD9731'
]
view.closest(github, palette)
# Out:
# <table style='border-collapse: collapse;'>
# <tr style='
#     border-bottom: 2px solid #deddda;
# '><th style='
#     text-align: center !important;
# '>color and its closest match</th><th style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>dist</th></tr>
#
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #1D8902;
# '>■ #1D8902  55 180 141  emerald green</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.000</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #1d8902;
# '>■ #1d8902  55 180 141  emerald green</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #0F5801;
# '>■ #0F5801  40 132 141  deep green</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.000</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #0f5801;
# '>■ #0f5801  40 132 141  deep green</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #116329;
# '>■ #116329  44 118 148  spruce</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.031</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #0f5801;
# '>■ #0f5801  40 132 141  deep green</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #01458F;
# '>■ #01458F  40 137 256  cobalt</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.090</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #002dbd;
# '>■ #002dbd  40 224 264  true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #0550AE;
# '>■ #0550AE  45 164 258  cobalt</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.070</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #002dbd;
# '>■ #002dbd  40 224 264  true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #0A3069;
# '>■ #0A3069  32 108 259  marine</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.103</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #025258;
# '>■ #025258  40  67 203  deep teal</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #316BCD;
# '>■ #316BCD  54 164 260  cornflower blue</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.085</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #1b5dff;
# '>■ #1b5dff  55 248 263  bright blue</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #0163F7;
# '>■ #0163F7  55 234 261  bright blue</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.018</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #1b5dff;
# '>■ #1b5dff  55 248 263  bright blue</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #8250DF;
# '>■ #8250DF  56 207 295  purpley</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.051</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #9335df;
# '>■ #9335df  55 240 305  violet</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #800080;
# '>■ #800080  42 193 328  darkish purple</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.017</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #76017a;
# '>■ #76017a  40 185 327  darkish purple</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #82071E;
# '>■ #82071E  39 151  21  wine red</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.022</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #8b010c;
# '>■ #8b010c  40 163  27  crimson</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #CF222E;
# '>■ #CF222E  55 205  25  cherry</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.020</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #d50118;
# '>■ #d50118  55 223  27  red</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #CD3131;
# '>■ #CD3131  56 193  26  reddish</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.031</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #d50118;
# '>■ #d50118  55 223  27  red</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #8B010C;
# '>■ #8B010C  40 163  27  crimson</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.000</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #8b010c;
# '>■ #8b010c  40 163  27  crimson</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #D50118;
# '>■ #D50118  55 223  2

# %% [markdown]
# ## ANSI colors
#
# The six original [ANSI colors](https://en.wikipedia.org/wiki/ANSI_escape_code#3-bit_and_4-bit) as pinned down by the [XKCD color survey](https://blog.xkcd.com/2010/05/03/color-survey-results/).

# %%
ansi_colors = [
    view.XKCD_COLORS["xkcd:" + name] for name in 
    ["red", "green", "blue", "yellow", "magenta", "cyan"]
]
view.closest(ansi_colors, palette)
# Out:
# <table style='border-collapse: collapse;'>
# <tr style='
#     border-bottom: 2px solid #deddda;
# '><th style='
#     text-align: center !important;
# '>color and its closest match</th><th style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>dist</th></tr>
#
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #e50000;
# '>■ #e50000  58 238  29  red</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.025</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #d50118;
# '>■ #d50118  55 223  27  red</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #15b01a;
# '>■ #15b01a  66 215 143  green</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.006</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #00ae0d;
# '>■ #00ae0d  65 219 143  green</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #0343df;
# '>■ #0343df  47 241 263  blue</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.048</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #002dbd;
# '>■ #002dbd  40 224 264  true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #ffff14;
# '>■ #ffff14  97 209 110  yellow</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.168</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #dca401;
# '>■ #dca401  75 154  84  burnt yellow</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #c20078;
# '>■ #c20078  53 221 353  magenta</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.032</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #c6048e;
# '>■ #c6048e  55 232 346  magenta</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #00ffff;
# '>■ #00ffff  91 155 195  cyan</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.234</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #008189;
# '>■ #008189  55  93 202  dark cyan</td>
# </tr></table>

# %% [markdown]
# ## Rainbow
#
# Colors of rainbow can be useful for [bracket pair colorization](https://code.visualstudio.com/updates/v1_60#_high-performance-bracket-pair-colorization)

# %%
rainbow_colors = [
    view.XKCD_COLORS["xkcd:" + name] for name in 
    ["red", "orange", "yellow", "green", "blue", "violet"]
]
view.closest(rainbow_colors, palette)
# Out:
# <table style='border-collapse: collapse;'>
# <tr style='
#     border-bottom: 2px solid #deddda;
# '><th style='
#     text-align: center !important;
# '>color and its closest match</th><th style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>dist</th></tr>
#
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #e50000;
# '>■ #e50000  58 238  29  red</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.025</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #d50118;
# '>■ #d50118  55 223  27  red</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #f97306;
# '>■ #f97306  70 188  49  orange</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.043</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #db7201;
# '>■ #db7201  66 162  55  pumpkin</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #ffff14;
# '>■ #ffff14  97 209 110  yellow</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.168</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #dca401;
# '>■ #dca401  75 154  84  burnt yellow</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #15b01a;
# '>■ #15b01a  66 215 143  green</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.006</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #00ae0d;
# '>■ #00ae0d  65 219 143  green</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #0343df;
# '>■ #0343df  47 241 263  blue</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.048</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #002dbd;
# '>■ #002dbd  40 224 264  true blue</td>
# </tr>
# <tr style='
#     background: #fff;
#
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #9a0eea;
# '>■ #9a0eea  55 276 306  violet</td>
#
# <td rowspan='2' style='
#     text-align: center !important;
#     background: #f6f5f4;
# '>0.037</td></tr>
# <tr style='
#     background: #fff;
#     border-bottom: 2px solid #deddda;
# '>
# <td style='
#     font-family: monospace;
#     text-align: left !important;
#     white-space: pre;
#     color: #9335df;
# '>■ #9335df  55 240 305  violet</td>
# </tr></table>
